# %% [markdown]
# # Project: Mobile Price Classification
#
# ## Table of Contents
# <ul>
# <li><a href="#intro">Introduction</a></li>
# <li><a href="#wrangling">Data Wrangling</a></li>
# <li><a href="#eda">Exploratory Data Analysis</a></li>
# <li><a href="#eda">Machine Learning Model</a></li>
# <li><a href="#conclusions">Conclusions</a></li>
# </ul>

# %% [markdown]
# # <a id='intro'></a>
# ## Introduction
#
# Bob has started his own mobile company. He wants to give tough fight to big companies like Apple,Samsung etc.
#
# He does not know how to estimate price of mobiles his company creates. In this competitive mobile phone market you cannot simply assume things. To solve this problem he collects sales data of mobile phones of various companies.
#
# Bob wants to find out some relation between features of a mobile phone(eg:- RAM,Internal Memory etc) and its selling price. But he is not so good at Machine Learning. So he needs your help to solve this problem.
#
# In this problem you do not have to predict actual price but a price range indicating how high the price is.
#
# **Dataset variable description as follows:**
#
# **ID: ID**
#
# **battery_power: Total energy a battery can store in one time measured in mAh**
#
# **blue: Has bluetooth or not**
#
# **clock_speed: speed at which microprocessor executes instructions**
#
# **dual_sim: Has dual sim support or not**
#
# **fc: Front Camera mega pixels**
#
# **four_g: Has 4G or not**
#
# **int_memory: Internal Memory in Gigabytes**
#
# **m_dep: Mobile Depth in cm**
#
# **mobile_wt: Weight of mobile phone**
#
# **n_cores: Number of cores of processor**
#
# **pc: Primary Camera mega pixels**
#
# **px_height: Pixel Resolution Height**
#
# **px_width: Pixel Resolution Width**
#
# **ram: Random Access Memory in Megabytes**
#
# **sc_h: Screen Height of mobile in cm**
#
# **sc_w: Screen Width of mobile in cm**
#
# **talk_time: longest time that a single battery charge will last when you are**
#
# **three_g: Has 3G or not**
#
# **touch_screen: Has touch screen or not**
#
# **wifi: Has wifi or not**

# %% [markdown]
# ## 1. Data Wrangling

# %% [markdown]
# ## 1.1) Importing Libraries

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_validate, GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.metrics import classification_report, accuracy_score, f1_score, confusion_matrix

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# <a id='wrangling'></a>
# ## 1.2) load the dataset and creating data frames

# %%
# Load the data and create a train dataframe
train_df = pd.read_csv("train.csv")
train_df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
#    three_g  touch_screen  wifi  price_range
# 0        0             0     1            1
# 1        1             1     0            2
# 2        1             1     0            2
# 3        1             0     0            2
# 4        1             1     0            1
#
# [5 rows x 21 columns]

# %%
# display the dimensions of the train dataset
train_df.shape
# Out:
# (2000, 21)

# %%
# Display the describtive statistics of the train dataset
train_df.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# min       0.000000     2.000000     0.100000    80.000000     1.000000  ...
# 25%       0.000000    16.000000     0.200000   109.000000     3.000000  ...
# 50%       1.000000    32.000000     0.500000   141.000000     4.000000  ...
# 75%       1.000000    48.000000     0.800000   170.000000     7.000000  ...
# max       1.000000    64.000000     1.000000   200.000000     8.000000  ...
#
#          px_height     px_width          ram         sc_h         sc_w  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean    645.108000  1251.515500  2124.213000    12.306500     5.767000
# std     443.780811   432.199447  1084.732044     4.213245     4.356398
# min       0.000000   500.000000   256.000000     5.000000     0.000000
# 25%     282.750000   874.750000  1207.500000     9.000000     2.000000
# 50%     564.000000  1247.000000  2146.500000    12.000000     5.000000
# 75%     947.250000  1633.000000  3064.500000    16.000000     9.000000
# max    1960.000000  1998.000000  3998.000000    19.000000    18.000000
#
#          talk_time      three_g  touch_screen         wifi  price_range
# count  2000.000000  2000.000000   2000.000000  2000.000000  2000.000000
# mean     11.011000     0.761500      0.503000     0.507000     1.500000
# std       5.463955     0.426273      0.500116     0.500076     1.118314
# min       2.000000     0.000000      0.000000     0.000000     0.000000
# 25%       6.000000     1.000000      0.000000     0.000000     0.750000
# 50%      11.000000     1.000000      1.000000     1.000000     1.500000
# 75%      16.000000     1.000000      1.000000     1.000000     2.250000
# max      20.000000     1.000000      1.000000     1.000000     3.000000
#
# [8 rows x 21 columns]

# %%
# Load the data and create a train dataframe
test_df = pd.read_csv("test.csv")
test_df.head()
# Out:
#    id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0   1           1043     1          1.8         1  14       0           5
# 1   2            841     1          0.5         1   4       1          61
# 2   3           1807     1          2.8         0   1       0          27
# 3   4           1546     0          0.5         1  18       1          25
# 4   5           1434     0          1.4         0  11       1          49
#
#    m_dep  mobile_wt  ...  pc  px_height  px_width   ram  sc_h  sc_w  \
# 0    0.1        193  ...  16        226      1412  3476    12     7
# 1    0.8        191  ...  12        746       857  3895     6     0
# 2    0.9        186  ...   4       1270      1366  2396    17    10
# 3    0.5         96  ...  20        295      1752  3893    10     0
# 4    0.5        108  ...  18        749       810  1773    15     8
#
#    talk_time  three_g  touch_screen  wifi
# 0          2        0             1     0
# 1          7        1             0     0
# 2         10        0             1     1
# 3          7        1             1     0
# 4          7        1             0     1
#
# [5 rows x 21 columns]

# %%
# display the dimensions of the train dataset
test_df.shape
# Out:
# (1000, 21)

# %%
# Display the describtive statistics of the train dataset
test_df.describe()
# Out:
#                 id  battery_power         blue  clock_speed     dual_sim  \
# count  1000.000000    1000.000000  1000.000000  1000.000000  1000.000000
# mean    500.500000    1248.510000     0.516000     1.540900     0.517000
# std     288.819436     432.458227     0.499994     0.829268     0.499961
# min       1.000000     500.000000     0.000000     0.500000     0.000000
# 25%     250.750000     895.000000     0.000000     0.700000     0.000000
# 50%     500.500000    1246.500000     1.000000     1.500000     1.000000
# 75%     750.250000    1629.250000     1.000000     2.300000     1.000000
# max    1000.000000    1999.000000     1.000000     3.000000     1.000000
#
#                 fc       four_g   int_memory        m_dep   mobile_wt  ...  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000  ...
# mean      4.593000     0.487000    33.652000     0.517500   139.51100  ...
# std       4.463325     0.500081    18.128694     0.280861    34.85155  ...
# min       0.000000     0.000000     2.000000     0.100000    80.00000  ...
# 25%       1.000000     0.000000    18.000000     0.300000   109.75000  ...
# 50%       3.000000     0.000000    34.500000     0.500000   139.00000  ...
# 75%       7.000000     1.000000    49.000000     0.800000   170.00000  ...
# max      19.000000     1.000000    64.000000     1.000000   200.00000  ...
#
#                 pc    px_height     px_width          ram         sc_h  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean     10.054000   627.121000  1239.774000  2138.998000    11.995000
# std       6.095099   432.929699   439.670981  1088.092278     4.320607
# min       0.000000     0.000000   501.000000   263.000000     5.000000
# 25%       5.000000   263.750000   831.750000  1237.250000     8.000000
# 50%      10.000000   564.500000  1250.000000  2153.500000    12.000000
# 75%      16.000000   903.000000  1637.750000  3065.500000    16.000000
# max      20.000000  1907.000000  1998.000000  3989.000000    19.000000
#
#               sc_w    talk_time      three_g  touch_screen         wifi
# count  1000.000000  1000.000000  1000.000000    1000.00000  1000.000000
# mean      5.316000    11.085000     0.756000       0.50000     0.507000
# std       4.240062     5.497636     0.429708       0.50025     0.500201
# min       0.000000     2.000000     0.000000       0.00000     0.000000
# 25%       2.000000     6.750000     1.000000       0.00000     0.000000
# 50%       5.000000    11.000000     1.000000       0.50000     1.000000
# 75%       8.000000    16.000000     1.000000       1.00000     1.000000
# max      18.000000    20.000000     1.000000       1.00000     1.000000
#
# [8 rows x 21 columns]

# %%
# check the info of the data frame 
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
#  18  touch_screen   2000 non-null   int64
#  19  wifi           2000 non-null   int64
#  20  price_range    2000 non-null   int64
# dtypes: float64(2), int64(19)
# memory usage: 328.2 KB

# %%
# check the info of the data frame 
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             1000 non-null   int64
#  1   battery_power  1000 non-null   int64
#  2   blue           1000 non-null   int64
#  3   clock_speed    1000 non-null   float64
#  4   dual_sim       1000 non-null   int64
#  5   fc             1000 non-null   int64
#  6   four_g         1000 non-null   int64
#  7   int_memory     1000 non-null   int64
#  8   m_dep          1000 non-null   float64
#  9   mobile_wt      1000 non-null   int64
#  10  n_cores        1000 non-null   int64
#  11  pc             1000 non-null   int64
#  12  px_height      1000 non-null   int64
#  13  px_width       1000 non-null   int64
#  14  ram            1000 non-null   int64
#  15  sc_h           1000 non-null   int64
#  16  sc_w           1000 non-null   int64
#  17  talk_time      1000 non-null   int64
#  18  three_g        1000 non-null   int64
#  19  touch_screen   1000 non-null   int64
#  20  wifi           1000 non-null   int64
# dtypes: float64(2), int64(19)
# memory usage: 164.2 KB

# %% [markdown]
# we can notice that there are no missing values for either train or test dataset.

# %% [markdown]
# **There are 21 variables with two data types Numerical and categorical:**
#
# **A) Numerical variables:**
#   - **Continuous type:**
#         1) id
#         2) battery_power
#         3) clock_speed
#         4) fc
#         5) int_memory
#         6) m_dep
#         7) mobile_wt
#         8) pc
#         9) px_height
#         10) px_width
#         11) ram
#         12) sc_h
#         13) sc_w
#         14) talk_time
#         15) n_cores
#
# **B) Categorical variables:**
#   - **Ordinal:**
#         1) blue
#         2) dual_sim
#         3) four_g
#         4) three_g
#         5) touch_screen
#         6) wifi
#         7) price_range

# %% [markdown]
# ## 1.3) Data Cleaning

# %% [markdown]
# In data cleaning section,

# %% [markdown]
# ### 1.3.1) check Duplicated data

# %%
pd.DataFrame(data = [train_df.duplicated().sum(), test_df.duplicated().sum()], index=["Train df duplicates", "Test df duplicates"]).T.style.background_gradient(cmap='YlOrRd')
# Out:
# <style type="text/css">
# #T_9b83e_row0_col0, #T_9b83e_row0_col1 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# </style>
# <table id="T_9b83e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Train df duplicates</th>
#       <th class="col_heading level0 col1" >Test df duplicates</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9b83e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9b83e_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_9b83e_row0_col1" class="data row0 col1" >0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 1.3.2) check the unique values.

# %%
#check the unique value of the train and test data frame. from the above shape , test_df rows = 2000, test_df rows =1000
pd.DataFrame(data = [train_df.groupby('wifi').nunique(dropna=True).sum(),test_df.groupby('wifi').nunique(dropna=True).sum()], index = ["Train df unique val", "Test df unique val"]).T.style.background_gradient(cmap='YlOrRd')
# Out:
# <style type="text/css">
# #T_ccff0_row0_col0 {
#   background-color: #ca0923;
#   color: #f1f1f1;
# }
# #T_ccff0_row0_col1 {
#   background-color: #c70723;
#   color: #f1f1f1;
# }
# #T_ccff0_row1_col0, #T_ccff0_row1_col1, #T_ccff0_row3_col0, #T_ccff0_row3_col1, #T_ccff0_row5_col0, #T_ccff0_row5_col1, #T_ccff0_row17_col0, #T_ccff0_row17_col1, #T_ccff0_row18_col0, #T_ccff0_row18_col1, #T_ccff0_row19_col0 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_ccff0_row2_col0, #T_ccff0_row14_col1 {
#   background-color: #fffcc4;
#   color: #000000;
# }
# #T_ccff0_row2_col1 {
#   background-color: #fff8bb;
#   color: #000000;
# }
# #T_ccff0_row4_col0, #T_ccff0_row10_col0 {
#   background-color: #fffcc5;
#   color: #000000;
# }
# #T_ccff0_row4_col1, #T_ccff0_row15_col1, #T_ccff0_row16_col1 {
#   background-color: #fffac1;
#   color: #000000;
# }
# #T_ccff0_row6_col0 {
#   background-color: #fff5b5;
#   color: #000000;
# }
# #T_ccff0_row6_col1 {
#   background-color: #ffeda1;
#   color: #000000;
# }
# #T_ccff0_row7_col0 {
#   background-color: #fffec9;
#   color: #000000;
# }
# #T_ccff0_row7_col1, #T_ccff0_row15_col0, #T_ccff0_row16_col0 {
#   background-color: #fffdc6;
#   color: #000000;
# }
# #T_ccff0_row8_col0 {
#   background-color: #ffec9d;
#   color: #000000;
# }
# #T_ccff0_row8_col1 {
#   background-color: #fedb7b;
#   color: #000000;
# }
# #T_ccff0_row9_col0 {
#   background-color: #fffecb;
#   color: #000000;
# }
# #T_ccff0_row9_col1, #T_ccff0_row14_col0 {
#   background-color: #fffdc8;
#   color: #000000;
# }
# #T_ccff0_row10_col1 {
#   background-color: #fffac0;
#   color: #000000;
# }
# #T_ccff0_row11_col0, #T_ccff0_row12_col0 {
#   background-color: #c90823;
#   color: #f1f1f1;
# }
# #T_ccff0_row11_col1 {
#   background-color: #ce0c22;
#   color: #f1f1f1;
# }
# #T_ccff0_row12_col1 {
#   background-color: #c40524;
#   color: #f1f1f1;
# }
# #T_ccff0_row13_col0, #T_ccff0_row20_col1 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_ccff0_row13_col1 {
#   background-color: #a10026;
#   color: #f1f1f1;
# }
# #T_ccff0_row19_col1, #T_ccff0_row20_col0 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ccff0_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Train df unique val</th>
#       <th class="col_heading level0 col1" >Test df unique val</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ccff0_level0_row0" class="row_heading level0 row0" >battery_power</th>
#       <td id="T_ccff0_row0_col0" class="data row0 col0" >1472.000000</td>
#       <td id="T_ccff0_row0_col1" class="data row0 col1" >842.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ccff0_level0_row1" class="row_heading level0 row1" >blue</th>
#       <td id="T_ccff0_row1_col0" class="data row1 col0" >4.000000</td>
#       <td id="T_ccff0_row1_col1" class="data row1 col1" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ccff0_level0_row2" class="row_heading level0 row2" >clock_speed</th>
#       <td id="T_ccff0_row2_col0" class="data row2 col0" >52.000000</td>
#       <td id="T_ccff0_row2_col1" class="data row2 col1" >52.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ccff0_level0_row3" class="row_heading level0 row3" >dual_sim</th>
#       <td id="T_ccff0_row3_col0" class="data row3 col0" >4.000000</td>
#       <td id="T_ccff0_row3_col1" class="data row3 col1" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ccff0_level0_row4" class="row_heading level0 row4" >fc</th>
#       <td id="T_ccff0_row4_col0" class="data row4 col0" >39.000000</td>
#       <td id="T_ccff0_row4_col1" class="data row4 col1" >38.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ccff0_level0_row5" class="row_heading level0 row5" >four_g</th>
#       <td id="T_ccff0_row5_col0" class="data row5 col0" >4.000000</td>
#       <td id="T_ccff0_row5_col1" class="data row5 col1" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ccff0_level0_row6" class="row_heading level0 row6" >int_memory</th>
#       <td id="T_ccff0_row6_col0" class="data row6 col0" >126.000000</td>
#       <td id="T_ccff0_row6_col1" class="data row6 col1" >126.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ccff0_level0_row7" class="row_heading level0 row7" >m_dep</th>
#       <td id="T_ccff0_row7_col0" class="data row7 col0" >20.000000</td>
#       <td id="T_ccff0_row7_col1" class="data row7 col1" >20.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ccff0_level0_row8" class="row_heading level0 row8" >mobile_wt</th>
#       <td id="T_ccff0_row8_col0" class="data row8 col0" >242.000000</td>
#       <td id="T_ccff0_row8_col1" class="data row8 col1" >239.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ccff0_level0_row9" class="row_heading level0 row9" >n_cores</th>
#       <td id="T_ccff0_row9_col0" class="data row9 col0" >16.000000</td>
#       <td id="T_ccff0_row9_col1" class="data row9 col1" >16.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ccff0_level0_row10" class="row_heading level0 row10" >pc</th>
#       <td id="T_ccff0_row10_col0" class="data row10 col0" >42.000000</td>
#       <td id="T_ccff0_row10_col1" class="data row10 col1" >42.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ccff0_level0_row11" class="row_heading level0 row11" >px_height</th>
#       <td id="T_ccff0_row11_col0" class="data row11 col0" >1476.000000</td>
#       <td id="T_ccff0_row11_col1" class="data row11 col1" >820.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ccff0_level0_row12" class="row_heading level0 row12" >px_width</th>
#       <td id="T_ccff0_row12_col0" class="data row12 col0" >1477.000000</td>
#       <td id="T_ccff0_row12_col1" class="data row12 col1" >852.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ccff0_level0_row13" class="row_heading level0 row13" >ram</th>
#       <td id="T_ccff0_row13_col0" class="data row13 col0" >1773.000000</td>
#       <td id="T_ccff0_row13_col1" class="data row13 col1" >931.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ccff0_level0_row14" class="row_heading level0 row14" >sc_h</th>
#       <td id="T_ccff0_row14_col0" class="data row14 col0" >30.000000</td>
#       <td id="T_ccff0_row14_col1" class="data row14 col1" >30.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ccff0_level0_row15" class="row_heading level0 row15" >sc_w</th>
#       <td id="T_ccff0_row15_col0" class="data row15 col0" >38.000000</td>
#       <td id="T_ccff0_row15_col1" class="data row15 col1" >38.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ccff0_level0_row16" class="row_heading level0 row16" >talk_time</th>
#       <td id="T_ccff0_row16_col0" class="data row16 col0" >38.000000</td>
#       <td id="T_ccff0_row16_col1" class="data row16 col1" >38.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ccff0_level0_row17" class="row_heading level0 row17" >three_g</th>
#       <td id="T_ccff0_row17_col0" class="data row17 col0" >4.000000</td>
#       <td id="T_ccff0_row17_col1" class="data row17 col1" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ccff0_level0_row18" class="row_heading level0 row18" >touch_screen</th>
#       <td id="T_ccff0_row18_col0" class="data row18 col0" >4.000000</td>
#       <td id="T_ccff0_row18_col1" class="data row18 col1" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ccff0_level0_row19" class="row_heading level0 row19" >price_range</th>
#       <td id="T_ccff0_row19_col0" class="data row19 col0" >8.000000</td>
#       <td id="T_ccff0_row19_col1" class="data row19 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_ccff0_level0_row20" class="row_heading level0 row20" >id</th>
#       <td id="T_ccff0_row20_col0" class="data row20 col0" >nan</td>
#       <td id="T_ccff0_row20_col1" class="data row20 col1" >1000.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 2. Exploratory Data Analysis
# This section includes analysis and visualization

# %% [markdown]
# From the heatmap plot, we will explore the correlation between phone price and other features. it is noticed that phone price is highly correlate with Ram feature and slightly correlated with px_width, px_height and batter_power features.
# let's search for correlation between the independed features. if correlation is found between two features,then we can drop one feature from them.
# it seems there is a slightly high correlation between pc feature(Primary Camera mega pixels) and fc feature (Front Camera mega pixels).
# There is a correlation as well between px_width and px_height, sc_width and sc_height and four_g and three_g..
# let's discover more using differnt seaborn plots.

# %%
# Heatmap plot for train dataset
f,ax = plt.subplots(figsize=(20, 20))
sns.heatmap(train_df.corr(), robust=True, annot=True, linewidths=.5, fmt= '.1f',ax=ax)
plt.title('Train data heat map plot')
# Out:
# Text(0.5, 1.0, 'Train data heat map plot')

# %%
# Heatmap plot for test dataset
f,ax = plt.subplots(figsize=(20, 20))
sns.heatmap(test_df.corr(), robust=True, annot=True, linewidths=.5, fmt= '.1f',ax=ax)
plt.title('Test data heat map plot');

# %%
# Create a histogram plot for all the dataset variables
train_df.hist(figsize=(20,15));

# %% [markdown]
# Histogram plot is quite helpful to quickly identify the data types of each features

# %%
cat_features = ['blue','dual_sim','four_g','three_g','touch_screen','wifi']
num_features = ['battery_power','clock_speed','fc','int_memory','m_dep','mobile_wt','n_cores','pc',
                'px_height','px_width','ram','sc_h','sc_w','talk_time']
y ='price_range'

# %%
def cat_plot(data, feature):
    fig, ax = plt.subplots(1, 2, figsize=(12, 4))
    #plot Pie plot for a categorical variable
    data[feature].value_counts().plot(kind="pie", explode=[0.05 for x in data[feature].dropna().unique()], autopct='%1.1f%%', ax=ax[0], shadow=True)
    ax[0].set_title(f"{feature} Pie Chart")
    ax[0].set_ylabel('')
    # Count plot for a categorical variable using bars
    count = sns.countplot(x=feature, data=data, ax=ax[1])
    for bar in count.patches:
        count.annotate(format(bar.get_height()),
            (bar.get_x() + bar.get_width() / 2,
            bar.get_height()), ha='center', va='center',
            size=11, xytext=(0, 8),
            textcoords='offset points')
    ax[1].set_title(f"{feature} Bar Chart")
    plt.show()

def num_plot(data, feature, target):
    fig, ax = plt.subplots(1, 2, figsize=(12, 4))
    #plot histogram and box plot for the numerical variables
    sns.histplot(data=data, x=feature, hue=target, kde=True, ax=ax[0])
    sns.boxplot(data=data, x=feature, ax=ax[1])
    ax[0].set_title(f"{feature} Distribution Histogram")
    ax[1].set_title(f"{feature} Distribution Boxplot")

    plt.show()

# %%
# Display price range pie plot and bar plot
cat_plot(train_df,y);

# %% [markdown]
# There are Four price ranges equally distributed

# %%
# Display the pie plot and bar plot for all the categorical features in the train data

for feature in cat_features:
    cat_plot(train_df,feature);

# %%
# Display the pie plot and bar plot for all the categorical features in the test data

for feature in cat_features:
    cat_plot(test_df,feature);

# %% [markdown]
# For either in train data and test data: almost half of the phones are having bluetooth, dual sim, four g, touch screen and wifi, except for the three g feature, around 75% of the phones having three g feature.

# %% [markdown]
# Let's check the count of phones who has wifi option grouped by price range. It is almost equal.

# %%
train_df.groupby('price_range')['wifi'].value_counts()
# Out:
# price_range  wifi
# 0            0       252
#              1       248
# 1            1       252
#              0       248
# 2            1       252
#              0       248
# 3            1       262
#              0       238
# Name: wifi, dtype: int64

# %%
#create a data frame to compare the count of cat. variables with rescpect to price range. In order to check if there is correlation between these features and price range.
pd.DataFrame(data = [train_df.groupby('price_range')['wifi'].value_counts(), train_df.groupby('price_range')['blue'].value_counts(),train_df.groupby('price_range')['dual_sim'].value_counts(),train_df.groupby('price_range')['three_g'].value_counts(),train_df.groupby('price_range')['four_g'].value_counts(),train_df.groupby('price_range')['touch_screen'].value_counts()], index=["Train wifi", "Train blue","Train dual_sim","Train Three_g","Train four_g","Train Touch_screen"]).T.style.background_gradient(cmap='YlOrRd')
# Out:
# <style type="text/css">
# #T_95e68_row0_col0, #T_95e68_row3_col0, #T_95e68_row5_col0 {
#   background-color: #fc6330;
#   color: #f1f1f1;
# }
# #T_95e68_row0_col1, #T_95e68_row4_col1 {
#   background-color: #b60026;
#   color: #f1f1f1;
# }
# #T_95e68_row0_col2, #T_95e68_row1_col2 {
#   background-color: #fd8c3c;
#   color: #f1f1f1;
# }
# #T_95e68_row0_col3 {
#   background-color: #fff8ba;
#   color: #000000;
# }
# #T_95e68_row0_col4 {
#   background-color: #fec45f;
#   color: #000000;
# }
# #T_95e68_row0_col5 {
#   background-color: #fff1a9;
#   color: #000000;
# }
# #T_95e68_row1_col0, #T_95e68_row2_col0, #T_95e68_row4_col0 {
#   background-color: #fea647;
#   color: #000000;
# }
# #T_95e68_row1_col1, #T_95e68_row5_col1 {
#   background-color: #ffefa5;
#   color: #000000;
# }
# #T_95e68_row1_col3 {
#   background-color: #990026;
#   color: #f1f1f1;
# }
# #T_95e68_row1_col4 {
#   background-color: #f13624;
#   color: #f1f1f1;
# }
# #T_95e68_row1_col5 {
#   background-color: #b00026;
#   color: #f1f1f1;
# }
# #T_95e68_row2_col1 {
#   background-color: #da141e;
#   color: #f1f1f1;
# }
# #T_95e68_row2_col2 {
#   background-color: #febf5a;
#   color: #000000;
# }
# #T_95e68_row2_col3 {
#   background-color: #fffac1;
#   color: #000000;
# }
# #T_95e68_row2_col4 {
#   background-color: #fed673;
#   color: #000000;
# }
# #T_95e68_row2_col5 {
#   background-color: #ffec9d;
#   color: #000000;
# }
# #T_95e68_row3_col1 {
#   background-color: #fede80;
#   color: #000000;
# }
# #T_95e68_row3_col2 {
#   background-color: #f43d25;
#   color: #f1f1f1;
# }
# #T_95e68_row3_col3 {
#   background-color: #8f0026;
#   color: #f1f1f1;
# }
# #T_95e68_row3_col4 {
#   background-color: #e51e1d;
#   color: #f1f1f1;
# }
# #T_95e68_row3_col5 {
#   background-color: #c00225;
#   color: #f1f1f1;
# }
# #T_95e68_row4_col2 {
#   background-color: #fd7c37;
#   color: #f1f1f1;
# }
# #T_95e68_row4_col3, #T_95e68_row5_col5, #T_95e68_row6_col0, #T_95e68_row6_col1, #T_95e68_row6_col2, #T_95e68_row6_col4 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_95e68_row4_col4 {
#   background-color: #fd6e33;
#   color: #f1f1f1;
# }
# #T_95e68_row4_col5, #T_95e68_row5_col3, #T_95e68_row7_col0, #T_95e68_row7_col1, #T_95e68_row7_col2, #T_95e68_row7_col4 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_95e68_row5_col2 {
#   background-color: #fd9740;
#   color: #000000;
# }
# #T_95e68_row5_col4 {
#   background-color: #fd9f44;
#   color: #000000;
# }
# #T_95e68_row6_col3 {
#   background-color: #fffecb;
#   color: #000000;
# }
# #T_95e68_row6_col5 {
#   background-color: #fc6a32;
#   color: #f1f1f1;
# }
# #T_95e68_row7_col3 {
#   background-color: #820026;
#   color: #f1f1f1;
# }
# #T_95e68_row7_col5 {
#   background-color: #fea145;
#   color: #000000;
# }
# </style>
# <table id="T_95e68_">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Train wifi</th>
#       <th class="col_heading level0 col1" >Train blue</th>
#       <th class="col_heading level0 col2" >Train dual_sim</th>
#       <th class="col_heading level0 col3" >Train Three_g</th>
#       <th class="col_heading level0 col4" >Train four_g</th>
#       <th class="col_heading level0 col5" >Train Touch_screen</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >price_range</th>
#       <th class="index_name level1" >&nbsp;</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_95e68_level0_row0" class="row_heading level0 row0" rowspan="2">0</th>
#       <th id="T_95e68_level1_row0" class="row_heading level1 row0" >0</th>
#       <td id="T_95e68_row0_col0" class="data row0 col0" >252</td>
#       <td id="T_95e68_row0_col1" class="data row0 col1" >257</td>
#       <td id="T_95e68_row0_col2" class="data row0 col2" >250</td>
#       <td id="T_95e68_row0_col3" class="data row0 col3" >127</td>
#       <td id="T_95e68_row0_col4" class="data row0 col4" >241</td>
#       <td id="T_95e68_row0_col5" class="data row0 col5" >238</td>
#     </tr>
#     <tr>
#       <th id="T_95e68_level1_row1" class="row_heading level1 row1" >1</th>
#       <td id="T_95e68_row1_col0" class="data row1 col0" >248</td>
#       <td id="T_95e68_row1_col1" class="data row1 col1" >243</td>
#       <td id="T_95e68_row1_col2" class="data row1 col2" >250</td>
#       <td id="T_95e68_row1_col3" class="data row1 col3" >373</td>
#       <td id="T_95e68_row1_col4" class="data row1 col4" >259</td>
#       <td id="T_95e68_row1_col5" class="data row1 col5" >262</td>
#     </tr>
#     <tr>
#       <th id="T_95e68_level0_row2" class="row_heading level0 row2" rowspan="2">1</th>
#       <th id="T_95e68_level1_row2" class="row_heading level1 row2" >0</th>
#       <td id="T_95e68_row2_col0" class="data row2 col0" >248</td>
#       <td id="T_95e68_row2_col1" class="data row2 col1" >255</td>
#       <td id="T_95e68_row2_col2" class="data row2 col2" >245</td>
#       <td id="T_95e68_row2_col3" class="data row2 col3" >122</td>
#       <td id="T_95e68_row2_col4" class="data row2 col4" >238</td>
#       <td id="T_95e68_row2_col5" class="data row2 col5" >239</td>
#     </tr>
#     <tr>
#       <th id="T_95e68_level1_row3" class="row_heading level1 row3" >1</th>
#       <td id="T_95e68_row3_col0" class="data row3 col0" >252</td>
#       <td id="T_95e68_row3_col1" class="data row3 col1" >245</td>
#       <td id="T_95e68_row3_col2" class="data row3 col2" >255</td>
#       <td id="T_95e68_row3_col3" class="data row3 col3" >378</td>
#       <td id="T_95e68_row3_col4" class="data row3 col4" >262</td>
#       <td id="T_95e68_row3_col5" class="data row3 col5" >261</td>
#     </tr>
#     <tr>
#       <th id="T_95e68_level0_row4" class="row_heading level0 row4" rowspan="2">2</th>
#       <th id="T_95e68_level1_row4" class="row_heading level1 row4" >0</th>
#       <td id="T_95e68_row4_col0" class="data row4 col0" >248</td>
#       <td id="T_95e68_row4_col1" class="data row4 col1" >257</td>
#       <td id="T_95e68_row4_col2" class="data row4 col2" >251</td>
#       <td id="T_95e68_row4_col3" class="data row4 col3" >113</td>
#       <td id="T_95e68_row4_col4" class="data row4 col4" >253</td>
#       <td id="T_95e68_row4_col5" class="data row4 col5" >265</td>
#     </tr>
#     <tr>
#       <th id="T_95e68_level1_row5" class="row_heading level1 row5" >1</th>
#       <td id="T_95e68_row5_col0" class="data row5 col0" >252</td>
#       <td id="T_95e68_row5_col1" class="data row5 col1" >243</td>
#       <td id="T_95e68_row5_col2" class="data row5 col2" >249</td>
#       <td id="T_95e68_row5_col3" class="data row5 col3" >387</td>
#       <td id="T_95e68_row5_col4" class="data row5 col4" >247</td>
#       <td id="T_95e68_row5_col5" class="data row5 col5" >235</td>
#     </tr>
#     <tr>
#       <th id="T_95e68_level0_row6" class="row_heading level0 row6" rowspan="2">3</th>
#       <th id="T_95e68_level1_row6" class="row_heading level1 row6" >0</th>
#       <td id="T_95e68_row6_col0" class="data row6 col0" >238</td>
#       <td id="T_95e68_row6_col1" class="data row6 col1" >241</td>
#       <td id="T_95e68_row6_col2" class="data row6 col2" >235</td>
#       <td id="T_95e68_row6_col3" class="data row6 col3" >115</td>
#       <td id="T_95e68_row6_col4" class="data row6 col4" >225</td>
#       <td id="T_95e68_row6_col5" class="data row6 col5" >252</td>
#     </tr>
#     <tr>
#       <th id="T_95e68_level1_row7" class="row_heading level1 row7" >1</th>
#       <td id="T_95e68_row7_col0" class="data row7 col0" >262</td>
#       <td id="T_95e68_row7_col1" class="data row7 col1" >259</td>
#       <td id="T_95e68_row7_col2" class="data row7 col2" >265</td>
#       <td id="T_95e68_row7_col3" class="data row7 col3" >385</td>
#       <td id="T_95e68_row7_col4" class="data row7 col4" >275</td>
#       <td id="T_95e68_row7_col5" class="data row7 col5" >248</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The above data frame shows the count of price range with each of the categorical feature. It seems that they are equal expect for three_g and touch screen feature. By this summary, the categorical features does not seem have an impact on the price range. these features will be deleted.

# %% [markdown]
# Let's explore the impact of the numerical variables on the price range

# %%
# Display the pie plot and bar plot for all the numerical features in the train data

for feature in num_features:
    num_plot(train_df,feature,y);

# %% [markdown]
# The above histogram plot for the numerical variables displays high correlation with ram variable, and minor correlation with battery power, px_width and px_height. there are outliers in fc and px_height.
# let's use the four features (ram, battery power, px height and px width) in building the machine learning model.

# %% [markdown]
# ## 3. Implement Machine Learning model
# This section includes buidling the machine learning model.

# %%
train_df.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
# let's remove the unwanted features from the dataset
drop_list = ['blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
       'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'sc_h', 
       'sc_w', 'talk_time', 'three_g','touch_screen', 'wifi','price_range']
X = train_df.drop(drop_list, axis=1)
y = train_df.price_range
#X_test = test_df.drop(drop_list[:-1], axis=1)
#X_test.drop('id',axis=1, inplace=True)
Xtest = test_df.drop(drop_list[:-1], axis=1)
Xtest.drop('id', axis=1, inplace=True)
Xtest
# Out:
#      battery_power  px_height  px_width   ram
# 0             1043        226      1412  3476
# 1              841        746       857  3895
# 2             1807       1270      1366  2396
# 3             1546        295      1752  3893
# 4             1434        749       810  1773
# ..             ...        ...       ...   ...
# 995           1700        644       913  2121
# 996            609       1152      1632  1933
# 997           1185        477       825  1223
# 998           1533         38       832  2509
# 999           1270        457       608  2828
#
# [1000 rows x 4 columns]

# %%
X.shape
# Out:
# (2000, 4)

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 40)

# %%
scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# Selecting the best classifier

# %%
classifiers = {
    "KNN": KNeighborsClassifier(), 
    "LR": LogisticRegression(max_iter=1000), 
    "DT": DecisionTreeClassifier(),
    "RF": RandomForestClassifier(),
    "SVM": SVC(),
    "MLP": MLPClassifier(max_iter=1000),
    "XGB": XGBClassifier(),
    "LGBM": LGBMClassifier()
}


def ml_model(models, X_train, X_test, y_train, y_test):    
    model_scores = {}
    
    for name, model in classifiers.items():
        model.fit(X_train, y_train)
        
        model_scores[name] = model.score(X_test, y_test)
    return model_scores
#results["Avg_Overall"] = (results["Avg_Accuracy"] + results["Avg_F1_Score"]) / 2
#results = results.sort_values("Avg_Overall", ascending=False)
#results

# %%
model_scores = ml_model(models=classifiers, 
                             X_train=X_train,
                            X_test=X_test,
                            y_train=y_train,
                            y_test=y_test)
model_scores
# Out:
# [21:13:30] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# {'KNN': 0.9166666666666666,
#  'LR': 0.9566666666666667,
#  'DT': 0.8716666666666667,
#  'RF': 0.92,
#  'SVM': 0.9416666666666667,
#  'MLP': 0.9633333333333334,
#  'XGB': 0.9166666666666666,
#  'LGBM': 0.9216666666666666}

# %% [markdown]
# ### 3.1) Hyperparameter Tuning

# %%
lr = LogisticRegression()
params = {
    "penalty": ("l1", "l2", "elasticnet"),
    "tol": (0.1, 0.01, 0.001, 0.0001),
    "C": (10.0, 1.0, 0.1, 0.01)
}
clf = GridSearchCV(lr, params, cv=10)
clf.fit(X_train, y_train)
print("Best hyperparameter:", clf.best_params_)
# Out:
# Best hyperparameter: {'C': 10.0, 'penalty': 'l2', 'tol': 0.1}

# %%
y_pred = clf.predict(X_train)
print(f"Train Accuracy: {accuracy_score(y_train, y_pred)}")
#print(f"Train F1-Score: {f1_score(y_train, y_pred)}")
sns.heatmap(confusion_matrix(y_train, y_pred), fmt='.3g', annot=True, cmap='summer_r')
plt.show()
# Out:
# Train Accuracy: 0.96

# %%
print(classification_report(y_train, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98       337
#            1       0.95      0.97      0.96       350
#            2       0.94      0.93      0.94       361
#            3       0.96      0.97      0.96       352
#
#     accuracy                           0.96      1400
#    macro avg       0.96      0.96      0.96      1400
# weighted avg       0.96      0.96      0.96      1400

# %% [markdown]
# ### 3.2) submission

# %%
y_pred = clf.predict(Xtest)

# %% [markdown]
# conclusion:
# Two models got high scores, LogisticRegression and MLPClassifier. Hyper parameter tunning done for Logistic regression classifier.

# %% [markdown]
# The score of the model matches with the features selection.
